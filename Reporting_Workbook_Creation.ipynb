# %%
Our target is https://nv5inc.sharepoint.com/:x:/r/sites/DTEEnergy-PotentialStudy/_layouts/15/Doc.aspx?sourcedoc=%7B50F00EFF-7727-4B9C-BA74-9B8B87B0135D%7D&file=ReportingTemplate_Scenario_MI_LInonLI_Template.xlsm&action=default&mobileredirect=true
