# %%
# this code creates a unique list of measures

# %%
# this code creates a unique list of competition groups

# %%
#this code makes a unique list of building types

# %%
# this code makes a template file for market characterization which is 
efficiency_level_breakout _> condition_name	competition_group	subgroup	single_family	multi_family	single_family_li	multi_family_li
equipment_count_per_building -> electric_utility	gas_utility	single_family	single_family_li	multi_family	multi_family_li
customer_building_type_count -> competition_group	subgroup	single_family	multi_family	single_family_li	multi_family_li
