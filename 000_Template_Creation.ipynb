# %%
# import needed libraries
import numpy as np
import pandas as pd
import openpyxl
from openpyxl import Workbook
from openpyxl.worksheet.datavalidation import DataValidation

# %%
def clean_column_names(df):
    df.columns = df.columns.str.lower().str.replace(' ', '_').str.replace('$', 'usd').str.replace('/', 'per').str.replace('&', 'and').str.replace('.', '')
    return df

# %%
def clean_values(df):
    # Apply cleaning to all string columns
    for col in df.columns:
        if df[col].dtype == 'object':  # Only process string columns
            df[col] = df[col].astype(str).str.lower().str.replace(' ', '_')
    return df

# %%
df_input = pd.read_excel('./00_input/00_Potential_Study_Input_Template.xlsx', sheet_name='Measure_List')
clean_column_names(df_input)
clean_values(df_input)
# Out:
#    measure_name  market         fuel  efficiency_levels       sector  \
# 0       furnace  ret_er          oil                  1  residential
# 1       furnace  ret_er  natural_gas                  1  residential
# 2  refrigerator      md     electric                  2  residential
# 3  refrigerator  ret_er     electric                  2  residential
#
#   competition_group    sub_group characterization_unit climate_zone_relevance  \
# 0   heating_cooling  oil_furnace                widget                      y
# 1   heating_cooling  gas_furnace                widget                      y
# 2     refrigeration    full_size                widget                      n
# 3     refrigeration    full_size                widget                      n
#
#   feasibility_constraint
# 0                      y
# 1                      y
# 2                      y
# 3                      y

# %%
df_global = pd.read_excel('./00_input/00_Potential_Study_Input_Template.xlsx', sheet_name='Global_Inputs')
clean_column_names(df_global)
clean_values(df_global)

# Extract length of analysis value
length_of_analysis = int(df_global.loc[df_global['screening_data'] == 'length_of_analysis', 'info'].values[0])
first_year_of_analysis = int(df_global.loc[df_global['screening_data'] == 'first_year_of_analysis', 'info'].values[0])

# Create a list of years from first_year_of_analysis to first_year_of_analysis + length_of_analysis
years_list = list(range(first_year_of_analysis, first_year_of_analysis + length_of_analysis))
years_list
# Out:
# [2026,
#  2027,
#  2028,
#  2029,
#  2030,
#  2031,
#  2032,
#  2033,
#  2034,
#  2035,
#  2036,
#  2037,
#  2038,
#  2039,
#  2040,
#  2041,
#  2042,
#  2043,
#  2044,
#  2045]

# %%
# Read utility combinations from input
df_utilities = pd.read_excel('./00_input/00_Potential_Study_Input_Template.xlsx', sheet_name='Utility_Combinations')
clean_column_names(df_utilities)
clean_values(df_utilities)
climate_zone_list = df_utilities['climate_zone'].unique().tolist()
# Each row is supposed to be aa unique combination that is present in the modelled territory no other combinations need to be made

# %%
# this code takes in the input sheet and makes the needed lists


# Measure list
# The input df_input has columns measure_name, market, fuel, sector, efficiency_levels
#The column efficiency_level will be a numeric value representing the number of efficiency levels for that measure
# this code will create a new row for each efficiency level for each measure and add a new column for efficiency level with the value being the level number

# additionally this code will check the climate_zone_relevance column and if it has a y it will create a new row for each climate zone from the unique climate_zones_list
# it will then append the climate_zone value to the condition_name column

rows_list = []
for index, row in df_input.iterrows():
    for level in range(1, row['efficiency_levels'] + 1):
        new_row = row.copy()
        new_row['efficiency_level'] = str(level)
        rows_list.append(new_row)

df_expanded = pd.DataFrame(rows_list).reset_index(drop=True)

# Expand for climate zones if climate_zone_relevance is 'y'
rows_list_climate = []
for index, row in df_expanded.iterrows():
    if row['climate_zone_relevance'] == 'y':
        # Create a row for each climate zone
        for climate_zone in climate_zone_list:
            new_row = row.copy()
            new_row['climate_zone'] = str(climate_zone)  # Convert to string
            rows_list_climate.append(new_row)
    else:
        # Keep the row as is, but add empty climate_zone column for consistency
        new_row = row.copy()
        new_row['climate_zone'] = ''
        rows_list_climate.append(new_row)

df_expanded = pd.DataFrame(rows_list_climate).reset_index(drop=True)

# Expand market column: if market is "md", create 3 rows with markets "rob", "nc", "reno"
df_expanded = df_expanded.copy()
rows_list_market = []
for index, row in df_expanded.iterrows():
    if row['market'] == 'md':
        # Create three rows for md markets
        for market_type in ['rob', 'nc', 'reno']:
            new_row = row.copy()
            new_row['market'] = market_type
            rows_list_market.append(new_row)
    else:
        # Keep the row as is
        rows_list_market.append(row)

df_expanded = pd.DataFrame(rows_list_market).reset_index(drop=True)

# # now if the market column has ret_er make two rows with a new column stock_level and in one row the value is baseline and the other value is existing
rows_list_stock = []
for index, row in df_expanded.iterrows():
    if row['market'] in ['ret_er', 'ret_add_on']:
        # Keep the original row with blank stock_level
        new_row = row.copy()
        new_row['stock_level'] = ''
        rows_list_stock.append(new_row)
        # Create two additional rows for ret_er markets with stock_level
        for stock in ['baseline', 'existing']:
            new_row = row.copy()
            new_row['stock_level'] = stock
            rows_list_stock.append(new_row)
    else:
        # Keep the row as is, but add empty stock_level column for consistency
        new_row = row.copy()
        new_row['stock_level'] = ''
        rows_list_stock.append(new_row)

df_expanded = pd.DataFrame(rows_list_stock).reset_index(drop=True)

# For nc, reno, or rob markets with efficiency_level = 1, create baseline row
rows_list_baseline = []
for index, row in df_expanded.iterrows():
    # Keep the original row
    rows_list_baseline.append(row.copy())
    
    # Check if market is nc, reno, or rob AND efficiency_level is 1
    if row['market'] in ['nc', 'reno', 'rob'] and row['efficiency_level'] == '1':
        # Create a baseline row
        baseline_row = row.copy()
        baseline_row['efficiency_level'] = '0'
        baseline_row['stock_level'] = 'baseline'
        rows_list_baseline.append(baseline_row)

df_expanded = pd.DataFrame(rows_list_baseline).reset_index(drop=True)

# Now adjust efficiency_level based on stock_level
df_expanded.loc[df_expanded['stock_level'] == 'baseline', 'efficiency_level'] = '0'
df_expanded.loc[df_expanded['stock_level'] == 'existing', 'efficiency_level'] = '-1'

df_expanded.loc[df_expanded['efficiency_level'] == '1', 'stock_level'] = 'efficient'
df_expanded.loc[df_expanded['efficiency_level'] == '2', 'stock_level'] = 'top10'

# I want to concatenate these columns to create a unique measure name
df_expanded['unique_measure_name'] = df_expanded['measure_name'] + "_" + df_expanded['fuel'] +"_" + df_expanded['stock_level'] + "_" + df_expanded['sector'] # this was re arranged

# Append climate_zone to unique_measure_name if climate_zone is not empty
# Convert to string to ensure concatenation works
df_expanded['climate_zone'] = df_expanded['climate_zone'].astype(str)
df_expanded.loc[df_expanded['climate_zone'] != '', 'unique_measure_name'] = (
    df_expanded['unique_measure_name'] + "_" + df_expanded['climate_zone']
)

# Create unique competition_group and subgroup combinations
df_expanded['competition_subgroup'] = df_expanded['competition_group'] + "_" + df_expanded['sub_group']
df_expanded['measure_name_competition_subgroup'] = df_expanded['unique_measure_name'] + "_" + df_expanded['competition_group'] + "_" + df_expanded['sub_group']

#relevant lists
measure_list = df_expanded['unique_measure_name'].unique().tolist()

efficient_measure_list = df_expanded[~df_expanded['stock_level'].isin(['baseline', 'existing'])]['unique_measure_name'].unique().tolist()
competition_subgroup_list = df_expanded['competition_subgroup'].unique().tolist()
competition_group = df_expanded['competition_group'].unique().tolist()
subgroup = df_expanded['sub_group'].unique().tolist()
measure_name_competition_subgroup_list = df_expanded['measure_name_competition_subgroup'].unique().tolist() # I dont think the unique removes anything and hopefully it doesnt
sector_list = df_expanded['sector'].unique().tolist()
fuel_list = df_expanded['fuel'].unique().tolist() ## this might cause issues if electric or electricy used


df_expanded
# Out:
#     measure_name  market         fuel  efficiency_levels       sector  \
# 0        furnace  ret_er          oil                  1  residential
# 1        furnace  ret_er          oil                  1  residential
# 2        furnace  ret_er          oil                  1  residential
# 3        furnace  ret_er          oil                  1  residential
# 4        furnace  ret_er          oil                  1  residential
# 5        furnace  ret_er          oil                  1  residential
# 6        furnace  ret_er  natural_gas                  1  residential
# 7        furnace  ret_er  natural_gas                  1  residential
# 8        furnace  ret_er  natural_gas                  1  residential
# 9        furnace  ret_er  natural_gas                  1  residential
# 10       furnace  ret_er  natural_gas                  1  residential
# 11       furnace  ret_er  natural_gas                  1  residential
# ...

# %%
# Building type list
df_building_types = pd.read_excel('./00_input/00_Potential_Study_Input_Template.xlsx', sheet_name='Building_Types')
clean_column_names(df_building_types)
clean_values(df_building_types)
building_type_list = df_building_types['building_type'].unique().tolist()

# %%
df_vocabulary_enums = pd.read_excel('./00_input/00_Potential_Study_Input_Template.xlsx', sheet_name='Vocabulary_Enums')
clean_column_names(df_vocabulary_enums)
clean_values(df_vocabulary_enums)
fuel_type_list = df_vocabulary_enums['fuel_xx_type'].unique().tolist()
interaction_group_list = df_vocabulary_enums['interaction_group'].unique().tolist()
fuel_end_use_list = df_vocabulary_enums['fuel_xx_end_use'].unique().tolist()
fuel_unit_list = df_vocabulary_enums['fuel_xx_units'].unique().tolist()

# %%
df_programs = pd.read_excel('./00_input/00_Potential_Study_Input_Template.xlsx', sheet_name='Programs')
clean_column_names(df_programs)
clean_values(df_programs)
programs_list = df_programs['program'].unique().tolist()

# %%
# this code takes the measure list and makes the workpapers input excel workbook
# the workpapers workbook has a sheet for each measure in the measure list
# we recently added program fields dynamically based on programs_list

# Create workbook
wb = Workbook()
# Remove default sheet
if 'Sheet' in wb.sheetnames:
    wb.remove(wb['Sheet'])

# Define all field names
field_names = [
    'parent_condition_name',  # prepopulate from measure_name in df_expanded
    'condition_name', # prepopulate from unique_measure_name in df_expanded
    'primary_fuel', # prepopulate from fuel in df_expanded
    'efficiency_description',
    'efficiency_level',# prepopulate from efficiency_level in df_expanded
    'year_start_baseline_shift', # add drop down from years_list
    'year_end_baseline_shift',# add drop down from years_list
    'sector', # prepopulate from sector in df_expanded
    'unit_of_characterization', # prepopulate from unit_of_characterization in df_expanded
    'competition_group', # prepopulate from competition_group in df_expanded
    'heating_or_cooling', # add drop down from ['heating', 'cooling', 'both'] # might remove
    'subgroup', # prepopulate from subgroup in df_expanded
    'base_building_type', # add drop down from building_type_list
    'interaction_group', # add drop down from interaction_group_list
    'interaction_group_type', # add drop down from ['effector', 'effected', blank]
    'equipment_cost', # For any numeric value (including decimals)
    'equipment_cost_scale_procedure', # process options to be made in code and then put as drop downs here #options Standard or Manual
    'labor_cost_installation', # For any numeric value (including decimals)
    'effective_useful_life_yrs', # For whole numbers (integers) only
    'water_usage_gal', # For any numeric value (including decimals)
    'o_and_m_costs', # For any numeric value (including decimals)
    'secondary_hvac_heating_effect_flag', # check if needed
    'secondary_hvac_cooling_effect_flag', # check if needed
    'climate_zone', # add drop down from climate_zone_list 
    'RET_retirement_rate', # For any numeric value (including decimals)
    'RET_add_on_applicable', # Y/N drop down
    'RET_ER_applicable', # Y/N drop down
    'NC_applicable',  # Y/N drop down
    'ROB_applicable', # Y/N drop down
    'RENO_applicable', # Y/N drop down
    'DEMO_applicable', # Y/N drop down # recently added
    'equipment_savings_scale_procedure', # process options to be made in code and then put as drop downs here #options Standard or Manual
    #'fuel-end_use_combinations',
    'fuel_01_type',  # add drop down from  fuel_XX_type
    'fuel_01_consumption',# For any numeric value (including decimals)
    'fuel_01_units', # add drop down from  fuel_unit_list
    'fuel_01_end_use', # add drop down from  fuel_XX_end_use
    'fuel_02_type',  # add drop down from  fuel_XX_type
    'fuel_02_consumption',# For any numeric value (including decimals)
    'fuel_02_units', # add drop down from  fuel_unit_list
    'fuel_02_end_use', # add drop down from  fuel_XX_end_use
    'fuel_03_type',  # add drop down from  fuel_XX_type
    'fuel_03_consumption', # For any numeric value (including decimals)
    'fuel_03_units', # add drop down from  fuel_unit_list
    'fuel_03_end_use', # add drop down from  fuel_XX_end_use
    'fuel_04_type',  # add drop down from  fuel_XX_type
    'fuel_04_consumption',# For any numeric value (including decimals)

    #### Future possible enhancement: make the fuel type count dynamic as an input on the measure list. ####
    'fuel_04_units',
    'fuel_04_end_use',
    'fuel_05_type',
    'fuel_05_consumption',
    'fuel_05_units',
    'fuel_05_end_use',
    'fuel_06_type',
    'fuel_06_consumption',
    'fuel_06_units',
    'fuel_06_end_use',
    'fuel_07_type',
    'fuel_07_consumption',
    'fuel_07_units',
    'fuel_07_end_use',
    'fuel_08_type',
    'fuel_08_consumption',
    'fuel_08_units',
    'fuel_08_end_use',
    'fuel_09_type',
    'fuel_09_consumption',
    'fuel_09_units',
    'fuel_09_end_use',
    'fuel_10_type',
    'fuel_10_consumption',
    'fuel_10_units',
    'fuel_10_end_use',
    'fuel_11_type',
    'fuel_11_consumption',
    'fuel_11_units',
    'fuel_11_end_use',
    'fuel_12_type',
    'fuel_12_consumption',
    'fuel_12_units',
    'fuel_12_end_use',
    'fuel_13_type',
    'fuel_13_consumption',
    'fuel_13_units',
    'fuel_13_end_use',
    'fuel_14_type',
    'fuel_14_consumption',
    'fuel_14_units',
    'fuel_14_end_use',
    'fuel_15_type',
    'fuel_15_consumption',
    'fuel_15_units',
    'fuel_15_end_use',
    'fuel_16_type',
    'fuel_16_consumption',
    'fuel_16_units',
    'fuel_16_end_use',
    'fuel_17_type',
    'fuel_17_consumption',
    'fuel_17_units',
    'fuel_17_end_use',
    'reference'
]

# Dynamically add program fields from programs_list
# Each program gets a field like "program_name_applicable"
for program in programs_list:
    field_names.append(f'{program}_applicable')

# Function to clean sheet name for Excel compatibility
def clean_sheet_name(name):
    # Remove invalid characters for Excel sheet names: : \ / ? * [ ]
    invalid_chars = [':', '\\', '/', '?', '*', '[', ']']
    for char in invalid_chars:
        name = name.replace(char, '_')
    # Truncate to 31 characters (Excel limit)
    return name[:31]

# Track used sheet names to ensure uniqueness
used_sheet_names = set()

def get_unique_sheet_name(measure_name, climate_zone):
    """Create sheet name with climate zone at the front if present"""
    # If climate zone exists and is not empty, put it at the front
    if climate_zone and climate_zone != '':
        # Format: climate_zone_measurename
        base_name = f"{climate_zone}_{measure_name}"
    else:
        base_name = measure_name
    
    sheet_name = clean_sheet_name(base_name)
    
    # Ensure uniqueness (in case there are still duplicates)
    if sheet_name not in used_sheet_names:
        used_sheet_names.add(sheet_name)
        return sheet_name
    
    # If duplicate, append counter
    counter = 1
    while True:
        max_base_length = 31 - len(f"_{counter}")
        unique_name = f"{sheet_name[:max_base_length]}_{counter}"
        
        if unique_name not in used_sheet_names:
            used_sheet_names.add(unique_name)
            return unique_name
        counter += 1

# Create a sheet for each measure
for measure in measure_list:
    # Get the row from df_expanded for this measure to access climate_zone
    measure_data = df_expanded[df_expanded['unique_measure_name'] == measure].iloc[0]
    climate_zone_value = measure_data['climate_zone']
    
    # Get unique sheet name with climate zone at front
    sheet_name = get_unique_sheet_name(measure, climate_zone_value)
    ws = wb.create_sheet(title=sheet_name)
    # Add header with Value column
    ws.append(['Field', 'Value'])
    
    # Add all field names as rows in column A with prepopulated values in column B where applicable
    row_num = 2  # Start at row 2 (after header)
    for field in field_names:
        value = ''
        # Check if this field should be prepopulated
        if field == 'parent_condition_name':
            value = measure_data['measure_name']
        elif field == 'condition_name':
            value = measure_data['unique_measure_name']
        elif field == 'primary_fuel':
            value = measure_data['fuel']
        elif field == 'efficiency_level':
            value = measure_data['efficiency_level']
        elif field == 'sector':
            value = measure_data['sector']
        elif field == 'unit_of_characterization':
            value = measure_data['characterization_unit']
        elif field == 'competition_group':
            value = measure_data['competition_group']
        elif field == 'subgroup':
            value = measure_data['sub_group']
        elif field == 'climate_zone':
            # Prepopulate climate_zone from the measure data
            value = measure_data['climate_zone'] if measure_data['climate_zone'] != '' else ''
        elif field == 'interaction_group':
            # Default value is 'none'
            value = 'none'
        
        ws.append([field, value])
        
        # Add data validation for dropdown fields
        cell_ref = f'B{row_num}'
        
        if field in ['year_start_baseline', 'year_end_baseline']:
            # Create dropdown from years_list
            years_str = ','.join(map(str, years_list))
            dv = DataValidation(type="list", formula1=f'"{years_str}"', allow_blank=True)
            ws.add_data_validation(dv)
            dv.add(cell_ref)
        
        elif field == 'heating_or_cooling':
            # Create dropdown for heating/cooling/both
            dv = DataValidation(type="list", formula1='"heating,cooling,both"', allow_blank=True)
            ws.add_data_validation(dv)
            dv.add(cell_ref)
        
        elif field == 'base_building_type':
            # Create dropdown from building_type_list
            building_str = ','.join(building_type_list)
            dv = DataValidation(type="list", formula1=f'"{building_str}"', allow_blank=True)
            ws.add_data_validation(dv)
            dv.add(cell_ref)
        
        elif field == 'interaction_group':
            # Create dropdown from interaction_group_list
            interaction_str = ','.join(interaction_group_list)
            dv = DataValidation(type="list", formula1=f'"{interaction_str}"', allow_blank=True)
            #dv.prompt = "Interaction Group"
            #dv.promptTitle = "Select Interaction Group"
            #dv.prompt = "Select the interaction group this condition belongs to. Choose 'none' if this condition does not interact with other equipment. Interaction groups define which equipment types affect each other's savings."
            ws.add_data_validation(dv)
            dv.add(cell_ref)
        
        elif field == 'interaction_group_type':
            # Create dropdown for effector/effected (with blank allowed)
            dv = DataValidation(type="list", formula1='"effector,effected"', allow_blank=True)
            #dv.prompt = "Interaction Group Type"
            #dv.promptTitle = "Select Interaction Type"
            #dv.prompt = "Select 'effector' if this condition reduces the savings of other measures (e.g., insulation reduces HVAC savings). Select 'effected' if this condition's savings are reduced by other measures (e.g., HVAC equipment savings are reduced by envelope improvements). Leave blank if interaction_group is 'none'."
            ws.add_data_validation(dv)
            dv.add(cell_ref)

        elif field == 'climate_zone':
            # Create dropdown from climate_zone_list
            climate_zone_str = ','.join(map(str, climate_zone_list))
            dv = DataValidation(type="list", formula1=f'"{climate_zone_str}"', allow_blank=True)
            ws.add_data_validation(dv)
            dv.add(cell_ref)
        
        elif field in ['equipment_cost_scale_procedure', 'equipment_savings_scale_procedure']:
            # Create dropdown for Standard/Manual
            dv = DataValidation(type="list", formula1='"Standard,Manual"', allow_blank=True)
            ws.add_data_validation(dv)
            dv.add(cell_ref)
        
        elif field in ['RET_add_on_applicable', 'RET_ER_applicable', 'NC_applicable', 'ROB_applicable', 'RENO_applicable', 'DEMO_applicable']:
            # Create Y/N dropdown
            dv = DataValidation(type="list", formula1='"Y,N"', allow_blank=True)
            ws.add_data_validation(dv)
            dv.add(cell_ref)
        
        elif field.endswith('_applicable') and field.replace('_applicable', '') in programs_list:
            # Create Y/N dropdown for program applicability fields
            dv = DataValidation(type="list", formula1='"Y,N"', allow_blank=True)
            ws.add_data_validation(dv)
            dv.add(cell_ref)
        
        elif field == 'effective_useful_life_yrs':
            # For whole numbers (integers) only
            dv = DataValidation(type="whole", operator="greaterThanOrEqual", formula1="0", allow_blank=True)
            dv.errorStyle = 'stop'  # Prevents invalid data entry
            dv.showErrorMessage = True  # Show error popup
            dv.error = 'Please enter a whole number (integer) greater than or equal to 0'
            dv.errorTitle = 'Invalid Input'
            ws.add_data_validation(dv)
            dv.add(cell_ref)
        
        elif field in ['equipment_cost', 'labor_cost_installation', 'water_usage_gal', 'o_and_m_costs', 'RET_retirement_rate'] or (field.endswith('_consumption') and field.startswith('fuel_')):
            # For any numeric value (including decimals)
            dv = DataValidation(type="decimal", operator="greaterThanOrEqual", formula1="-999999999", allow_blank=True)
            dv.errorStyle = 'stop'  # Prevents invalid data entry
            dv.showErrorMessage = True  # Show error popup
            dv.error = 'Please enter a numeric value'
            dv.errorTitle = 'Invalid Input'
            ws.add_data_validation(dv)
            dv.add(cell_ref)
        
        elif field.endswith('_type') and field.startswith('fuel_'):
            # Create dropdown from fuel_type_list
            fuel_type_str = ','.join(fuel_type_list)
            dv = DataValidation(type="list", formula1=f'"{fuel_type_str}"', allow_blank=True)
            ws.add_data_validation(dv)
            dv.add(cell_ref)
        
        elif field.endswith('_units') and field.startswith('fuel_'):
            # Create dropdown from fuel_unit_list
            fuel_unit_str = ','.join(fuel_unit_list)
            dv = DataValidation(type="list", formula1=f'"{fuel_unit_str}"', allow_blank=True)
            ws.add_data_validation(dv)
            dv.add(cell_ref)
        
        elif field.endswith('_end_use') and field.startswith('fuel_'):
            # Create dropdown from fuel_end_use_list
            fuel_end_use_str = ','.join(fuel_end_use_list)
            dv = DataValidation(type="list", formula1=f'"{fuel_end_use_str}"', allow_blank=True)
            ws.add_data_validation(dv)
            dv.add(cell_ref)
        
        row_num += 1

# Save the workbook
wb.save('./00_output/workpapers.xlsx')
print(f"Workbook saved with {len(measure_list)} unique measure sheets")
# Out:
# Workbook saved with 16 unique measure sheets

# %%
#kwh-kw ratio table input sheet
# this code creates a excel workbook with a sheet for kwh-kw ratio table
# the kwh-kw table has columns parent_condition_name, enduse, and the list of building_type
# the first column parent_condition_name is populated with unique measure names from the measure list 
parent_measure_list = df_expanded['measure_name'].unique().tolist()

wb_kwh_kw = Workbook()
# Remove default sheet
if 'Sheet' in wb_kwh_kw.sheetnames:
    wb_kwh_kw.remove(wb_kwh_kw['Sheet'])

# Create the kwh-kw ratio sheet
ws_kwh_kw = wb_kwh_kw.create_sheet(title='kwh_kw_ratio')

# Create the header row with parent_condition_name, enduse, and all building types
headers = ['parent_condition_name', 'enduse'] + building_type_list
ws_kwh_kw.append(headers)

# Populate the parent_condition_name column with unique measure names
for measure_name in parent_measure_list:
    ws_kwh_kw.append([measure_name])

# Save the workbook
wb_kwh_kw.save('./00_output/kwh_kw_ratio.xlsx')

# %%
# this code creates the 02_market_characterization input excel workbook
# this workbook has three sheets 
# sheet one is customer_building_type_count which has columns Electric_utility, gas_utility, and every building type from building_type_list
# the values in Electric_utility, gas_utility, are populated from the input sheet Utility_Combinations which has columns electric_utility and gas_utility
# sheet two is equipment_count_per_building_type which has columns competition_group, subgroup populated from competition_group and subgroup lists and building_type populated from building_type_list
# sheet three is called efficiency_level_breakout and has columns measure_name, competition_group, subgroup and blank columns with building_type_list


# Create workbook
wb_market_char = Workbook()
# Remove default sheet
if 'Sheet' in wb_market_char.sheetnames:
    wb_market_char.remove(wb_market_char['Sheet'])

# Sheet 1: customer_building_type_count
ws_customer = wb_market_char.create_sheet(title='customer_building_type_count')
# Create headers
customer_headers = ['electric_utility', 'gas_utility', 'climate_zone'] + building_type_list
ws_customer.append(customer_headers)
# Populate with utility combinations
for index, row in df_utilities.iterrows():
    ws_customer.append([row['electric_utility'], row['gas_utility'], row['climate_zone']])
    
# Sheet 2: equipment_count_per_building
ws_equipment = wb_market_char.create_sheet(title='equipment_count_per_building')
# Create headers
equipment_headers = ['competition_group', 'subgroup','characterization_unit'] + building_type_list
ws_equipment.append(equipment_headers)
# Get unique combinations of competition_group, subgroup, and characterization_unit (drop duplicates BEFORE iterating)
unique_comp_sub = df_expanded[['competition_group', 'sub_group', 'characterization_unit']].drop_duplicates()
for index, row in unique_comp_sub.iterrows():
    ws_equipment.append([row['competition_group'], row['sub_group'], row['characterization_unit']])

# Sheet 3: efficiency_level_breakout
ws_efficiency = wb_market_char.create_sheet(title='efficiency_level_breakout')
# Create headers - split out measure_name_competition_subgroup into separate columns
efficiency_headers = ['competition_group', 'subgroup', 'condition'] + building_type_list
ws_efficiency.append(efficiency_headers)
# Populate with unique combinations from df_expanded
# Get unique combinations of competition_group, subgroup, and unique_measure_name
unique_combinations = df_expanded[['competition_group', 'sub_group', 'unique_measure_name']].drop_duplicates()
for index, row in unique_combinations.iterrows():
    ws_efficiency.append([row['competition_group'], row['sub_group'], row['unique_measure_name']])

# Save the workbook
wb_market_char.save('./00_output/02_market_characterization.xlsx')

# %%
df_ghgs = pd.read_excel('./00_input/00_Potential_Study_Input_Template.xlsx', sheet_name='GHGs')
clean_column_names(df_ghgs)
clean_values(df_ghgs)
df_periods = pd.read_excel('./00_input/00_Potential_Study_Input_Template.xlsx', sheet_name='Periods')
clean_column_names(df_periods)
clean_values(df_periods)
# Out:
#                  periods
# 0         summer_on-peak
# 1        summer_off-peak
# 2         winter_on-peak
# 3        winter_off-peak
# 4       shoulder_on-peak
# 5      shoulder_off-peak
# 6  summer_gener_capacity
# 7  winter_gener_capacity
# 8              summer_td
# 9              winter_td

# %%
ghgs_list = df_ghgs['ghgs'].unique().tolist()
periods_list = df_periods['periods'].unique().tolist()
sector_list = df_expanded['sector'].unique().tolist()
fuel_list = df_expanded['fuel'].unique().tolist()
years_list
# Out:
# [2026,
#  2027,
#  2028,
#  2029,
#  2030,
#  2031,
#  2032,
#  2033,
#  2034,
#  2035,
#  2036,
#  2037,
#  2038,
#  2039,
#  2040,
#  2041,
#  2042,
#  2043,
#  2044,
#  2045]

# %%
# Avoided Costs input workbook creation code will go here
# lists needed period, sectors, fuels, ghgs
# first column is year and populated with years_list the other columns have no values but the headers are each period from periods_list concat with "usdperKWH" 
# the other columns are each fuel type from fuel_list except "electric" concat with "usdperMMBtu" and sector from sector_list all unique combinations


##################
### water avoided cost needs to be added######
#############################################
# Create workbook
wb_avoided_costs = Workbook()
# Remove default sheet
if 'Sheet' in wb_avoided_costs.sheetnames:
    wb_avoided_costs.remove(wb_avoided_costs['Sheet'])

# Create the avoided costs sheet
ws_avoided_costs = wb_avoided_costs.create_sheet(title='avoided_costs')

# Build headers
# Start with 'year'
headers = ['year']

# Add period headers with "usdperKWH"
for period in periods_list:
    headers.append(f"{period}_usdperKWH")

# Add fuel/sector combination headers (excluding electric) with "usdperMMBtu"
non_electric_fuels = [fuel for fuel in fuel_list if fuel != 'electric']
for fuel in non_electric_fuels:
    for sector in sector_list:
        headers.append(f"{fuel}_{sector}_usdperMMBtu")

# Append headers to sheet
ws_avoided_costs.append(headers)

# Populate year column with years_list
for year in years_list:
    ws_avoided_costs.append([year])

# Save the workbook
wb_avoided_costs.save('./00_output/11_avoided_costs.xlsx')

# %%
# this code is the same as above but every column except year is appended to add a value from the ghgs_list 
# so that we have the same columns but now multiplied by the number of entries in the ghgs_list 
# and the ghgs_list value concat _ to the end of each column name

### WIll need to remove the demand Sections from the GHG avoided costs
wb_avoided_costs_ghg = Workbook()
# Remove default sheet
if 'Sheet' in wb_avoided_costs_ghg.sheetnames:
    wb_avoided_costs_ghg.remove(wb_avoided_costs_ghg['Sheet'])

# Create the avoided costs sheet
ws_avoided_costs_ghg = wb_avoided_costs_ghg.create_sheet(title='avoided_costs_ghg')

# Build headers
# Start with 'year'
headers = ['year']

# For each GHG, add all the period and fuel/sector columns
for ghg in ghgs_list:
    # Add period headers with "usdperKWH" and ghg suffix
    for period in periods_list:
        headers.append(f"{period}_usdperKWH_{ghg}")
    
    # Add fuel/sector combination headers (excluding electric) with "usdperMMBtu" and ghg suffix
    non_electric_fuels = [fuel for fuel in fuel_list if fuel != 'electric']
    for fuel in non_electric_fuels:
        for sector in sector_list:
            headers.append(f"{fuel}_{sector}_usdperMMBtu_{ghg}")

# Append headers to sheet
ws_avoided_costs_ghg.append(headers)

# Populate year column with years_list
for year in years_list:
    ws_avoided_costs_ghg.append([year])

# Save the workbook
wb_avoided_costs_ghg.save('./00_output/12_avoided_costs_ghg.xlsx')

# %%
# this cell creates the loadshape input excel workbook
# the loadshape workbook has columns unique_measure_name, and periods_list
#the values are from the unique_measure_name column

# Create workbook
wb_loadshape = Workbook()
# Remove default sheet
if 'Sheet' in wb_loadshape.sheetnames:
    wb_loadshape.remove(wb_loadshape['Sheet'])

# Create the loadshape sheet
ws_loadshape = wb_loadshape.create_sheet(title='loadshape')

# Build headers: unique_measure_name followed by all periods
headers = ['unique_measure_name'] + periods_list
ws_loadshape.append(headers)

# Populate unique_measure_name column with values from measure_list
for measure in measure_list:
    ws_loadshape.append([measure])

# Save the workbook
wb_loadshape.save('./00_output/12_loadshape.xlsx')

# %%
# incentives input workbook creation code will go here
# the incentives workbook has columns unique_measure_name, utility, electric_incentive_percentage, gas_incentive_percentage and nonutility_incentive_percentage
# the values in unique_measure_name are from measure_list
# the utility column is populated with unique utilities from the Utility_Combinations input sheet
# df_utilities has columns electric_utility and gas_utility they need to be combined into one utility column and made unique
# the measure_list is repeated for each utility with blank values for the incentive percentages

# we need all utilites in one column and the utility type (gas or electric) in another column
electric_utilities = df_utilities['electric_utility'].unique().tolist()
gas_utilities = df_utilities['gas_utility'].unique().tolist()
# if the measure is electric only they would not incentives the measure as a gas utility so we can remove those rows right? -------------------- for now we will leave it in
# same for gas only measures and electric utilities
# I need a connected column for utility type for each of these electric_utilities and gas_utilities
electric_utilities_with_type = [(utility, 'electric') for utility in electric_utilities]
gas_utilities_with_type = [(utility, 'gas') for utility in gas_utilities]

utility_list = list(set(electric_utilities_with_type + gas_utilities_with_type))



# Create workbook
wb_incentives = Workbook()
# Remove default sheet
if 'Sheet' in wb_incentives.sheetnames:
    wb_incentives.remove(wb_incentives['Sheet'])

# Create the incentives sheet
ws_incentives = wb_incentives.create_sheet(title='incentives')

# Build headers
headers = ['unique_measure_name', 'utility', 'utility_type', 'incentive_percentage']
ws_incentives.append(headers)

# Populate with efficient_measure_list repeated for each utility
for utility_tuple in utility_list:
    utility_name, utility_type = utility_tuple
    for measure in efficient_measure_list:
        ws_incentives.append([measure, utility_name, utility_type, ""])

# Save the workbook
wb_incentives.save('./00_output/13_incentives.xlsx')

# %%
# This code creates the program adjustments input workbook
# This allows for program-specific incentive and savings adjustments by measure, market, and utility

# Get unique combinations of measure_name and market
unique_measure_market = df_expanded[['unique_measure_name', 'market']].drop_duplicates().apply(tuple, axis=1).tolist()
# code to drop any values in unique_measure_name that have stock_level baseline or existing
unique_measure_market = [tup for tup in unique_measure_market if not any(suffix in tup[0] for suffix in ['_baseline', '_existing'])]

# Create workbook
wb_incentives_programs = Workbook()
# Remove default sheet
if 'Sheet' in wb_incentives_programs.sheetnames:
    wb_incentives_programs.remove(wb_incentives_programs['Sheet'])

# Create the programs adjustments sheet
ws_incentives_programs = wb_incentives_programs.create_sheet(title='programs_adjustments')

# Build headers
headers = ['unique_measure_name', 'market', 'utility', 'utility_type', 'program', 'incentive_adjustment_percentage', 'savings_adjustment_percentage']
ws_incentives_programs.append(headers)

# Populate with unique measure/market combinations for each program and utility
for program in programs_list:
    for utility_tuple in utility_list:
        utility_name, utility_type = utility_tuple
        for measure_market_tuple in unique_measure_market:
            measure_name, market = measure_market_tuple
            ws_incentives_programs.append([measure_name, market, utility_name, utility_type, program, '', ''])

# Save the workbook
wb_incentives_programs.save('./00_output/18_program_adjustments.xlsx')

# %%
# programs this code creates the programs input excel workbook
# the programs workbook has columns program, utility, fuel
# the values in utility are populated from the utility_list
# the values in fuel are populated from the fuel_list
# the values in the column are from programs_list
# there is a unique row for each combination of program, utility, and fuel
# there is a blank column called "non-incentive costs as a percent of incentive costs"


df_programs = pd.read_excel('./00_input/00_Potential_Study_Input_Template.xlsx', sheet_name='Programs')
clean_column_names(df_programs)
clean_values(df_programs)
programs_list = df_programs['program'].unique().tolist()

# Create workbook
wb_programs = Workbook()
# Remove default sheet
if 'Sheet' in wb_programs.sheetnames:
    wb_programs.remove(wb_programs['Sheet'])

# Create the programs sheet
ws_programs = wb_programs.create_sheet(title='programs')

# Build headers
headers = ['program', 'utility', 'fuel', 'non-incentive_costs_as_a_percent_of_incentive_costs']
ws_programs.append(headers)

# Populate with unique combinations of program, utility, and fuel
for program in programs_list:
    for utility in utility_list:
        for fuel in fuel_list:
            ws_programs.append([program, utility, fuel])

# Save the workbook
wb_programs.save('./00_output/14_programs.xlsx')

# %%
# this cell creates the 15_line_losses workbook
# the columns are sectors with values from sector_list and periods witch are column names found in periods_list

# Create workbook
wb_line_losses = Workbook()
# Remove default sheet
if 'Sheet' in wb_line_losses.sheetnames:
    wb_line_losses.remove(wb_line_losses['Sheet'])

# Create the line losses sheet
ws_line_losses = wb_line_losses.create_sheet(title='line_losses')

# Build headers: sector followed by all periods
headers = ['sector'] + periods_list
ws_line_losses.append(headers)

# Populate sector column with values from sector_list
for sector in sector_list:
    ws_line_losses.append([sector])

# Save the workbook
wb_line_losses.save('./00_output/15_line_losses.xlsx')

# %%
# this cell create the 16_measnonresource workbook 
# the columns are utility and other_nonresource_benefit 
# utility is populated with utility_list and other_nonresource_benefit is blank

# Create workbook
wb_nonresource = Workbook()
# Remove default sheet
if 'Sheet' in wb_nonresource.sheetnames:
    wb_nonresource.remove(wb_nonresource['Sheet'])

# Create the nonresource sheet
ws_nonresource = wb_nonresource.create_sheet(title='nonresource')

# Build headers
headers = ['utility', 'other_nonresource_benefit']
ws_nonresource.append(headers)

# Populate utility column with values from utility_list
for utility in utility_list:
    ws_nonresource.append([utility])

# Save the workbook
wb_nonresource.save('./00_output/16_nonresource.xlsx')

# %%
# this cell creates the 17_retail_rates workbook
# the columns are year, utility and a combination of fuel and sector from fuel_list and sector_list
# the year column is populated with years_list
# the utility column is populated with utility_list
# the fuel and sector combination columns are blank but the column names are each fuel from fuel_list concat with each sector from sector_list and usdperKWH for electric fuel and usdperMMBtu for other fuels

# Create workbook
wb_retail_rates = Workbook()
# Remove default sheet
if 'Sheet' in wb_retail_rates.sheetnames:
    wb_retail_rates.remove(wb_retail_rates['Sheet'])

# Create the retail rates sheet
ws_retail_rates = wb_retail_rates.create_sheet(title='retail_rates')

# Build headers
headers = ['year', 'utility']

# Add fuel/sector combination headers
for fuel in fuel_list:
    for sector in sector_list:
        if fuel == 'electric':
            headers.append(f"{fuel}_{sector}_usdperKWH")
        else:
            headers.append(f"{fuel}_{sector}_usdperMMBtu")

ws_retail_rates.append(headers)

# Populate with year and utility combinations
for year in years_list:
    for utility in utility_list:
        ws_retail_rates.append([year, utility])

# Save the workbook
wb_retail_rates.save('./00_output/17_retail_rates.xlsx')

# %%
# this cell creates the 20_alternative_competition_ratios input workbook
# the columns are unique_measure_name from measure_list and value which is blank

# Create workbook
wb_alt_comp = Workbook()
# Remove default sheet
if 'Sheet' in wb_alt_comp.sheetnames:
    wb_alt_comp.remove(wb_alt_comp['Sheet'])

# Create the alternative competition ratios sheet
ws_alt_comp = wb_alt_comp.create_sheet(title='alternative_competition_ratios')

# Build headers
headers = ['unique_measure_name', 'value']
ws_alt_comp.append(headers)

# Populate unique_measure_name column with values from measure_list
for measure in measure_list:
    ws_alt_comp.append([measure])

# Save the workbook
wb_alt_comp.save('./00_output/20_alternative_competition_ratios.xlsx')

# %%
# this cell creates 30_Construction_Inputs
# the workbook has three sheets called New_Construction, Demolition, Renovation
# all sheets are structured the same
# the columns are competition_subgroup populated from competition_subgroup_list 
# and the other columns are from building_type_list

### TODO 
# we will want to then filter this input sheet to only have the needed measures based on the workpapers if they have market applicable values for demo reno and nc

# Create workbook
wb_construction_rates = Workbook()
# Remove default sheet
if 'Sheet' in wb_construction_rates.sheetnames:
    wb_construction_rates.remove(wb_construction_rates['Sheet'])

# Define sheet names
sheet_names = ['New_Construction', 'Demolition', 'Renovation']

# Create each sheet with the same structure
for sheet_name in sheet_names:
    ws = wb_construction_rates.create_sheet(title=sheet_name)
    
    # Build headers
    headers = ['competition_subgroup'] + building_type_list
    ws.append(headers)
    
    # Populate competition_subgroup column
    for comp_subgroup in competition_subgroup_list:
        ws.append([comp_subgroup])

# Save the workbook
wb_construction_rates.save('./00_output/30_Construction_Inputs.xlsx')

# %%
# this cell creates 32_CI_Manual_Rate_of_change
# the workbook has three types of sheets called New_Construction, Demolition, Renovation
# but for each year in the study there is a sheet for each of these three options
# example New_Construction_2025, Demolition_2025, Renovation_2025
# all sheets are structured the same
# the columns are competition_subgroup populated from competition_subgroup_list 
# and the other columns are from building_type_list

### TODO 
# we will want to then filter this input sheet to only have the needed measures based on the workpapers if they have market applicable values for demo reno and nc

# Create workbook
wb_construction_rates_manual = Workbook()
# Remove default sheet
if 'Sheet' in wb_construction_rates_manual.sheetnames:
    wb_construction_rates_manual.remove(wb_construction_rates_manual['Sheet'])

# Define construction types
sheet_types = ['New_Construction', 'Demolition', 'Renovation']

# Create sheets for each year and each construction type
for year in years_list:
    for sheet_type in sheet_types:
        sheet_name = f"{sheet_type}_{year}"
        ws = wb_construction_rates_manual.create_sheet(title=sheet_name)
        
        # Build headers
        headers = ['competition_subgroup'] + building_type_list
        ws.append(headers)
        
        # Populate competition_subgroup column
        for comp_subgroup in competition_subgroup_list:
            ws.append([comp_subgroup])

# Save the workbook
wb_construction_rates_manual.save('./00_output/32_CI_Manual_Rate_of_change.xlsx')

# %%
# this cell creates 31_CI_Rate_of_change
# the workbook has three sheets called New_Construction, Demolition, Renovation
# all sheets are structured the same
# the columns are competition_subgroup populated from competition_subgroup_list 
# and the other columns are from building_type_list

### TODO 
# we will want to then filter this input sheet to only have the needed measures based on the workpapers if they have market applicable values for demo reno and nc

# Create workbook
wb_construction = Workbook()
# Remove default sheet
if 'Sheet' in wb_construction.sheetnames:
    wb_construction.remove(wb_construction['Sheet'])

# Define sheet names
sheet_names = ['New_Construction', 'Demolition', 'Renovation']

# Create each sheet with the same structure
for sheet_name in sheet_names:
    ws = wb_construction.create_sheet(title=sheet_name)
    
    # Build headers
    headers = ['competition_subgroup'] + building_type_list
    ws.append(headers)
    
    # Populate competition_subgroup column
    for comp_subgroup in competition_subgroup_list:
        ws.append([comp_subgroup])

# Save the workbook
wb_construction.save('./00_output/31_CI_Rate_of_change.xlsx')

# %%
# this cell creates 35_Feasibility_Inputs
# the workbook has one sheet called feasibility 
# - **Required Fields:**
#   - `measure_name` (string, this will have to match from the template and measure database)
#     - Description: this is the baseline to upgrade measure
#     - Example values: same set up as what comes out of the measure database for linking purposes
#   - `competition_group` (string, matches database)
#     - Description: used by the adoption model so it knows what group this feasibility piece fits into
#     - Example values: 
#   - `efficiency_level` (int)
#     - Description: efficiency level of the upgrade measure. this is needed so the adoption model can tell which relationship to limit
#     - Example values: [Examples]
#   - `building_type_feasibility` (float, needs to be a percentage generally higher than than 90%?)
#     - Description: this is the percentage of the standard adoption model's yearly results that actually happen in a given year 
#     - Example values: [.9]

# Start with df_expanded and filter efficiency_level > 0 (exclude baseline and existing)
df_feasibility = df_expanded[df_expanded['efficiency_level'].astype(int) > 0].copy()

# Filter to only include rows with 'y' in feasibility_constraint column
df_feasibility = df_feasibility[df_feasibility['feasibility_constraint'] == 'y']

# Create full_measure_name based on market type
# If market is ret_er, prefix with "existing_to_"
df_feasibility['full_measure_name'] = df_feasibility.apply(
    lambda row: f"existing_to_{row['unique_measure_name']}" if row['market'] == 'ret_er' 
    else row['unique_measure_name'], axis=1
)

# If market is rob, nc, or reno, prefix with "baseline_to_"
df_feasibility['full_measure_name'] = df_feasibility.apply(
    lambda row: f"baseline_to_{row['unique_measure_name']}" if row['market'] in ['rob', 'nc', 'reno']
    else row['full_measure_name'], axis=1
)

# Filter to only efficiency_levels 1 and 2 (stock_level 'efficient' and 'top10')
df_feasibility = df_feasibility[df_feasibility['stock_level'].isin(['efficient', 'top10'])]

# Get unique combinations for rows
unique_feasibility_measures = df_feasibility[['full_measure_name', 'competition_group', 'efficiency_level']].drop_duplicates()

# Create workbook
wb_feasibility = Workbook()
# Remove default sheet
if 'Sheet' in wb_feasibility.sheetnames:
    wb_feasibility.remove(wb_feasibility['Sheet'])

# Create the feasibility sheet
ws_feasibility = wb_feasibility.create_sheet(title='feasibility')

# Build headers: measure_name, competition_group, efficiency_level, then building types with _feasibility
headers = ['measure_name', 'competition_group', 'efficiency_level'] + [bt + '_feasibility' for bt in building_type_list]
ws_feasibility.append(headers)

# Populate rows with unique combinations
for index, row in unique_feasibility_measures.iterrows():
    ws_feasibility.append([row['full_measure_name'], row['competition_group'], row['efficiency_level']])

# Save the workbook
wb_feasibility.save('./00_output/35_Feasibility_Inputs.xlsx')

# %%
# this cell takes all the individually outputted workbooks and puts them into a single excel workbook

import os
from openpyxl import load_workbook
import re

# Create a new master workbook
master_wb = Workbook()
# Remove default sheet
if 'Sheet' in master_wb.sheetnames:
    master_wb.remove(master_wb['Sheet'])

# List of workbook files to combine (excluding workpapers.xlsx as it has too many sheets)
workbook_files = [
    './00_output/kwh_kw_ratio.xlsx',
    './00_output/02_market_characterization.xlsx',
    './00_output/11_avoided_costs.xlsx',
    './00_output/12_avoided_costs_ghg.xlsx', #might need to change
    './00_output/12_loadshape.xlsx',
    './00_output/13_incentives.xlsx',
    './00_output/14_programs.xlsx',
    './00_output/15_line_losses.xlsx',
    './00_output/16_nonresource.xlsx',
    './00_output/17_retail_rates.xlsx',
    './00_output/20_alternative_competition_ratios.xlsx',
    './00_output/30_Construction_Inputs.xlsx',
    './00_output/31_CI_Rate_of_change.xlsx',
    './00_output/32_CI_Manual_Rate_of_change.xlsx',
    './00_output/35_Feasibility_Inputs.xlsx'
]

# Read each workbook and copy sheets to master workbook
for file_path in workbook_files:
    if os.path.exists(file_path):
        wb = load_workbook(file_path)
        # Extract number from filename using regex
        filename = os.path.basename(file_path)
        number_match = re.search(r'(\d+)', filename)
        file_number = number_match.group(1) if number_match else ''
        
        for sheet_name in wb.sheetnames:
            source_sheet = wb[sheet_name]
            # Create new sheet name using file number and original sheet name
            if file_number:
                new_sheet_name = f"{file_number}_{sheet_name}"[:31]  # Excel sheet name limit
            else:
                new_sheet_name = sheet_name[:31]
            target_sheet = master_wb.create_sheet(title=new_sheet_name)
            
            # Copy all data from source to target
            for row in source_sheet.iter_rows():
                target_sheet.append([cell.value for cell in row])

# Save the master workbook
master_wb.save('./00_output/00_Master_Input_Template.xlsx')
print("Master workbook created successfully!")
# Out:
# Master workbook created successfully!
