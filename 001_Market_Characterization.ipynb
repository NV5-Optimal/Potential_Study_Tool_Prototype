# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# This code will take in three files that will be different sheets in the market characterization workbook. It will then multiply these values together to get to the initial count of every piece of equipment(condition) in the potential study.

# %%
#future cleaning functions here

# %%
#@task
def read_in_market_characterization_sheets(file_path: str = './001_input/00_Master_Input_Template.xlsx') -> tuple:
    """Read market characterization sheets from the Excel file and return individual dataframes"""
    # Define the sheets we want to read
    sheets = ['02_customer_building_type_count', '02_equipment_count_per_building', '02_efficiency_level_breakout']
    
    # Read all sheets at once
    all_dfs = pd.read_excel(file_path, sheet_name=sheets, header=0)
    
    # Extract individual dataframes
    customer_building_type_count = all_dfs[sheets[0]]
    equipment_count_per_building = all_dfs[sheets[1]]
    efficiency_level_breakout = all_dfs[sheets[2]]
    
    # Required columns to check
    #required_columns = {"single_family", "multi_family"}


    
    return customer_building_type_count, equipment_count_per_building, efficiency_level_breakout

# %%
#Calling the function above
customer_building_type_count, equipment_count_per_building, efficiency_level_breakout = read_in_market_characterization_sheets()

# %%
#Parameters
# This code makes a unique list of building types by looking at the column names in efficiency_level_breakout 
# and removing the measure_name, competition_group, and subgroup columns

# Get all columns from efficiency_level_breakout
all_columns = efficiency_level_breakout.columns.tolist()

# Define columns to exclude (non-building type columns)
exclude_columns = ['competition_group', 'subgroup', 'condition_name', 'condition']

# Filter to get only building type columns
building_types = [col for col in all_columns if col not in exclude_columns]

print(f"Building types identified: {building_types}")
# Out:
# Building types identified: ['single_family', 'multifamily', 'single_family_li', 'multifamily_li']

# %% [markdown]
# Combining first and second sheet (the number of customers in each building type and the number of equipment each customer has for that building type)

# %%
# Create a Cartesian product: each row in customer_building_type_count × all rows in equipment_count_per_building
# This ensures we have utility information for each equipment/condition combo

result_rows = []

# Iterate over each row in customer_building_type_count (each utility combo)
for cust_idx, cust_row in customer_building_type_count.iterrows():
    # For each equipment row
    for equip_idx, equip_row in equipment_count_per_building.iterrows():
        # Create a new row combining customer info and multiplied equipment counts
        new_row = {}
        
        # Copy non-building-type columns from customer row (e.g., electric_utility, gas_utility)
        for col in customer_building_type_count.columns:
            if col not in building_types:
                new_row[col] = cust_row[col]
        
        # Copy non-building-type columns from equipment row (e.g., competition_group, subgroup, condition_name)
        for col in equipment_count_per_building.columns:
            if col not in building_types:
                new_row[col] = equip_row[col]
        
        # Multiply each building type count: equipment_count × customer_building_count
        for building_type in building_types:
            equip_count = equip_row.get(building_type, 0)
            cust_count = cust_row.get(building_type, 0)
            new_row[building_type] = equip_count * cust_count
        
        result_rows.append(new_row)

# Create the new dataframe from the combined rows
equipment_count_total = pd.DataFrame(result_rows)

# %%
# Merge equipment_count_total and efficiency_level_breakout on 'condition_name' and 'competition_group'
merged_df = pd.merge(
    efficiency_level_breakout,
    equipment_count_total,
    on=["competition_group", "subgroup"],
    suffixes=("_eff", "_equip")
)

# Multiply building type columns where matches occur
for building_type in building_types:
    merged_df[building_type + "_year_one"] = merged_df[building_type + "_eff"] * merged_df[building_type + "_equip"]

 #Drop columns ending with _eff and _equip from merged_df",
cols_to_drop = [col for col in merged_df.columns if col.endswith('_eff') or col.endswith('_equip')]
df_yr1 = merged_df.drop(columns=cols_to_drop)
df_yr1
# Out:
#    competition_group     subgroup  \
# 0    heating_cooling  oil_furnace
# 1    heating_cooling  oil_furnace
# 2    heating_cooling  oil_furnace
# 3    heating_cooling  oil_furnace
# 4    heating_cooling  oil_furnace
# 5    heating_cooling  oil_furnace
# 6    heating_cooling  oil_furnace
# 7    heating_cooling  oil_furnace
# 8    heating_cooling  oil_furnace
# 9    heating_cooling  gas_furnace
# 10   heating_cooling  gas_furnace
# 11   heating_cooling  gas_furnace
# 12   heating_cooling  gas_furnace
# 13   heating_cooling  gas_furnace
# 14   heating_cooling  gas_furnace
# 15   heating_cooling  gas_furnace
# 16   heating_cooling  gas_furnace
# 17   heating_cooling  gas_furnace
# 18     refrigeration    full_size
# 19     refrigeration    full_size
# 20     refrigeration    full_size
# 21     refrigeration    full_size
# 22     refrigeration    full_size
# 23     refrigeration    full_size
# 24     refrigeration    full_size
# 25     refrigeration    full_size
# 26     refrigeration    full_size
# 27     refrigeration    full_size
# 28     refrigeration    full_size
# 29     refrigeration    full_size
#
#                                          condition electric_utility  \
# 0                furnace_oil_efficient_residential   test_utility_1
# 1                furnace_oil_efficient_residential   test_utility_1
# 2                furnace_oil_efficient_residential   test_utility_1
# 3                 furnace_oil_baseline_residential   test_utility_1
# 4                 furnace_oil_baseline_residential   test_utility_1
# 5                 furnace_oil_baseline_residential   test_utility_1
# 6                 furnace_oil_existing_residential   test_utility_1
# 7                 furnace_oil_existing_residential   test_utility_1
# 8                 furnace_oil_existing_residential   test_utility_1
# 9        furnace_natural_gas_efficient_residential   test_utility_1
# 10       furnace_natural_gas_efficient_residential   test_utility_1
# 11       furnace_natural_gas_efficient_residential   test_utility_1
# 12        furnace_natural_gas_baseline_residential   test_utility_1
# 13        furnace_natural_gas_baseline_residential   test_utility_1
# 14        furnace_natural_gas_baseline_residential   test_utility_1
# 15        furnace_natural_gas_existing_residential   test_utility_1
# 16        furnace_natural_gas_existing_residential   test_utility_1
# 17        furnace_natural_gas_existing_residential   test_utility_1
# 18  refrigerator_electricity_efficient_residential   test_utility_1
# 19  refrigerator_electricity_efficient_residential   test_utility_1
# 20  refrigerator_electricity_efficient_residential   test_utility_1
# 21   refrigerator_electricity_baseline_residential   test_utility_1
# 22   refrigerator_electricity_baseline_residential   test_utility_1
# 23   refrigerator_electricity_baseline_residential   test_utility_1
# 24      refrigerator_electricity_top10_residential   test_utility_1
# 25      refrigerator_electricity_top10_residential   test_utility_1
# 26      refrigerator_electricity_top10_residential   test_utility_1
# 27   refrigerator_electricity_existing_residential   test_utility_1
# 28   refrigerator_electricity_existing_residential   test_utility_1
# 29   refrigerator_electricity_existing_residential   test_utility_1
#
#        gas_utility  climate_zone  single_family_year_one  \
# 0   test_utility_1             1                  5000.0
# 1   test_utility_2             1                 10000.0
# 2             none             1                 27500.0
# 3   test_utility_1             1                  2500.0
# 4   test_utility_2             1                  5000.0
# 5             none             1                 13750.0
# 6   test_utility_1             1                  2500.0
# 7   test_utility_2             1                  5000.0
# 8             none             1                 13750.0
# 9   test_utility_1             1                  5000.0
# 10  test_utility_2             1                 10000.0
# 11            none             1                 27500.0
# 12  test_utility_1             1                  2500.0
# 13  test_utility_2             1                  5000.0
# 14            none             1                 13750.0
# 15  test_utility_1             1                  2500.0
# 16  test_utility_2             1                  5000.0
# 17            none             1                 13750.0
# 18  test_utility_1             1                 25000.0
# 19  test_utility_2             1                 50000.0
# 20            none             1                137500.0
# 21  test_utility_1             1                 25000.0
# 22  test_utility_2             1                 50000.0
# 23            none             1                137500.0
# 24  test_utility_1             1                     0.0
# 25  test_utility_2             1                     0.0
# 26            none             1                     0.0
# 27  test_utility_1             1                     0.0
# 28  test_utility_2             1                     0.0
# 29            none             1                     0.0
#
#     multifamily_year_one  single_family_li_year_one  multifamily_li_year_one
# 0                 2500.0                      500.0                    250.0
# 1                 5000.0                     2000.0                   1000.0
# 2                 4700.0                     1900.0                    700.0
# 3                 1250.0                      250.0                    125.0
# 4                 2500.0                     1000.0                    500.0
# 5                 2350.0                      950.0                    350.0
# 6                 1250.0                      250.0                    125.0
# 7                 2500.0                     1000.0                    500.0
# 8                 2350.0                      950.0                    350.0
# 9                 2500.0                      500.0                    250.0
# 10                5000.0                     2000.0                   1000.0
# 11                4700.0                     1900.0                    700.0
# 12                1250.0                      250.0                    125.0
# 13                2500.0                     1000.0                    500.0
# 14                2350.0                      950.0                    350.0
# 15                1250.0                      250.0                    125.0
# 16                2500.0                     1000.0                    500.0
# 17                2350.0                      950.0                    350.0
# 18               15000.0                     2500.0                   1500.0
# 19               30000.0                    10000.0                   6000.0
# 20               28200.0                     9500.0                   4200.0
# 21               15000.0                     2500.0                   1500.0
# 22               30000.0                    10000.0                   6000.0
# 23               28200.0                     9500.0                   4200.0
# 24                   0.0                        0.0                      0.0
# 25                   0.0                        0.0                      0.0
# 26                   0.0                        0.0                      0.0
# 27                   0.0                        0.0                      0.0
# 28                   0.0                        0.0                      0.0
# 29                   0.0                        0.0                      0.0

# %%
df_yr1.to_pickle("./001_output/df_yr1_001.pkl")
df_yr1.to_excel("./001_output/df_yr1_001.xlsx")
df_yr1.to_pickle("./020_input/df_yr1_001.pkl")
